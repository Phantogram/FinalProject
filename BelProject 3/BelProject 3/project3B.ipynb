# %%
# Import dependencies
import os
import csv
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns

# %%
#Read in csv
alltrack_path = os.path.join('Resources','all_type_track.csv')
alltrack_path
# Out:
# 'Resources\\all_type_track.csv'

# %%
atrack_type = pd.read_csv(alltrack_path)
atrack_type.head()
# Out:
#                        id                       name  \
# 0  4dn6rw5Ze1uWrLm1uOk1gu        Stockholm Sweetnin'
# 1  6CDQBADsdzJwc3qZ3OPDHH  Almost Like Being in Love
# 2  00CIFNT8kOm61dupysBFp8          Garden of Delight
# 3  2z6D5bIA9Wprdqi1B8nnVh                New Orleans
# 4  1ykNjOQbYJgZE3pflVB9MN                 The Sequel
#
#                                     uri  \
# 0  spotify:track:4dn6rw5Ze1uWrLm1uOk1gu
# 1  spotify:track:6CDQBADsdzJwc3qZ3OPDHH
# 2  spotify:track:00CIFNT8kOm61dupysBFp8
# 3  spotify:track:2z6D5bIA9Wprdqi1B8nnVh
# 4  spotify:track:1ykNjOQbYJgZE3pflVB9MN
#
#                                               artist  acousticness  \
# 0  Scott Hamilton, Jesper Lundgaard, Jan Lundgren...         0.838
# 1           Red Garland, Paul Chambers, Art Taylor,          0.873
# 2                                Jan Lundgren Trio,          0.876
# 3                                  Wynton Marsalis,          0.714
# ...

# %%
atrack_type.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   1477.000000   1476.000000  1.477000e+03  1477.000000
# mean       0.388480      0.559495  2.805558e+05     0.560785
# std        0.379412      0.187704  3.309670e+05     0.291691
# min        0.000023      0.058500  5.433300e+04     0.001540
# 25%        0.029700      0.452000  1.959970e+05     0.329000
# 50%        0.236000      0.594500  2.252000e+05     0.611000
# 75%        0.795000      0.694000  2.726270e+05     0.801000
# max        0.996000      0.967000  4.500037e+06     1.000000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       1477.000000  1477.000000  1477.000000  1477.000000  1477.000000
# mean           0.270535     5.140826     0.191479   -10.547395     0.580907
# std            0.388855     3.571066     0.164750     7.907770     0.493578
# min            0.000000     0.000000     0.022700   -41.808000     0.000000
# ...

# %%
atrack_type.shape
# Out:
# (1477, 19)

# %%
atrack_type.columns
# Out:
# Index(['id', 'name', 'uri', 'artist', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'Group', 'group_n'],
#       dtype='object')

# %%
#create paired graphs using track features

sns.pairplot(atrack_type, vars=['acousticness','danceability','energy','instrumentalness'], hue = 'Group')

# %%
# paired graphs based on track features

sns.pairplot(atrack_type, vars=['liveness','loudness','speechiness','tempo','valence'],hue = 'Group')

# %%
# Generate 4 clusters of random data.
from sklearn.datasets.samples_generator import make_blobs

atrack_type, _ = make_blobs(n_samples=600, centers=4,
                     cluster_std=0.70, random_state=0)
# Out:
# C:\Users\Belinda PC\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Plot the data
plt.scatter(atrack_type[:, 0],  atrack_type[:, 1])

# %%
# Use n_clusters=4 as the k value
# We can see from the plot above that there are 4 clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)

# %%
# Fit the model to the data
kmeans.fit(atrack_type)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Predict the clusters
predicted_clusters = kmeans.predict(atrack_type)

# %%
# Plot the predicted clusters to see if the model predicted the correct clusters
# This is visual validation that the model was trained correctly.
plt.scatter(atrack_type[:, 0], atrack_type[:, 1], c=predicted_clusters, s=50, cmap='viridis')
